# %%
import sys
import os
import logging
import time

sys.path.append(os.path.abspath(os.path.join(os.path.abspath(os.getcwd()), '../..')))
from jawm import Process, jawm_help

logging.basicConfig(level=logging.INFO)
os.environ['JAWM_MONITORING_DIRECTORY'] = 'monitoring'

# %%
fastqc_apptainer = Process(name="fastqc_apptainer", param_file="parameters/fastqc.yaml")
fastqc_apptainer.execute()
# Out:
# [2025-05-02 13:27:11] INFO:: [fastqc_apptainer|abde] Executing process fastqc_apptainer in Slurm
# [2025-05-02 13:27:11] INFO:: [fastqc_apptainer|abde] Log folder for process fastqc_apptainer: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/examples/fastqc/logs/fastqc_apptainer_20250502_132711_abde
# [2025-05-02 13:27:11] INFO:: [fastqc_apptainer|abde] Generating Slurm job script for process: fastqc_apptainer
# [2025-05-02 13:27:11] INFO:: [fastqc_apptainer|abde] Preparing base script for process fastqc_apptainer
# [2025-05-02 13:27:11] INFO:: [fastqc_apptainer|abde] Submitting process fastqc_apptainer with slurm command: sbatch --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/examples/fastqc/logs/fastqc_apptainer_20250502_132711_abde/fastqc_apptainer.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/examples/fastqc/logs/fastqc_apptainer_20250502_132711_abde/fastqc_apptainer.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/examples/fastqc/logs/fastqc_apptainer_20250502_132711_abde/fastqc_apptainer.slurm
# [2025-05-02 13:27:21] INFO:: [fastqc_apptainer|abde] Process fastqc_apptainer submitted as Slurm job 525161.
# [2025-05-02 13:27:31] INFO:: [fastqc_apptainer|abde] Slurm job 525161 completed with exit code: 0:0

# %%
# Inline Process Example

# fastqc_apptainer = Process(
#     name="fastqc_apptainer",
#     script="""#!/bin/bash
# mkdir output
# fastqc -o output/ input/reads.fastq
# """,
#     container="/nexus/posix0/MAGE-flaski/service/images/fastqc-0.11.9.sif",
#     environment="apptainer",
#     manager="slurm"
# )

# fastqc_apptainer.execute()
