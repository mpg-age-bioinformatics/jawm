# %%
import os
os.environ['JAWM_MONITORING_DIRECTORY'] = 'monitoring'

# For development
# import sys
# sys.path.append(os.path.abspath(os.path.join(os.path.abspath(os.getcwd()), '../..')))

from jawm import Process

# %%
fastqc_apptainer = Process(name="fastqc_apptainer", param_file="parameters/fastqc.yaml")
fastqc_apptainer.execute()
# Out:
# [2025-05-07 11:51:25] INFO:: [fastqc_apptainer|9513] Executing process fastqc_apptainer in Slurm
# [2025-05-07 11:51:25] INFO:: [fastqc_apptainer|9513] Log folder for process fastqc_apptainer: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/examples/fastqc/logs/fastqc_apptainer_20250507_115125_9513
# [2025-05-07 11:51:25] INFO:: [fastqc_apptainer|9513] Generating Slurm job script for process: fastqc_apptainer
# [2025-05-07 11:51:25] INFO:: [fastqc_apptainer|9513] Preparing base script for process fastqc_apptainer
# [2025-05-07 11:51:25] INFO:: [fastqc_apptainer|9513] Submitting process fastqc_apptainer with slurm command: sbatch --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/examples/fastqc/logs/fastqc_apptainer_20250507_115125_9513/fastqc_apptainer.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/examples/fastqc/logs/fastqc_apptainer_20250507_115125_9513/fastqc_apptainer.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/examples/fastqc/logs/fastqc_apptainer_20250507_115125_9513/fastqc_apptainer.slurm
# [2025-05-07 11:51:35] INFO:: [fastqc_apptainer|9513] Process fastqc_apptainer submitted as Slurm job 526248.
# [2025-05-07 11:51:56] INFO:: [fastqc_apptainer|9513] Slurm job 526248 completed with exit code: 0:0

# %%
# Inline Process Example

# fastqc_apptainer = Process(
#     name="fastqc_apptainer",
#     script="""#!/bin/bash
# mkdir output
# fastqc -o output/ input/reads.fastq
# """,
#     container="/nexus/posix0/MAGE-flaski/service/images/fastqc-0.11.9.sif",
#     environment="apptainer",
#     manager="slurm"
# )

# fastqc_apptainer.execute()
