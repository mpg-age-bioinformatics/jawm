# %%
import os
os.environ['JAWM_MONITORING_DIRECTORY'] = 'monitoring'

# For development
# sys.path.append(os.path.abspath(os.path.join(os.path.abspath(os.getcwd()), '..')))

from jawm import Process

# %%
### Hello World example
process_hw = Process(
    name="hello_world",
    script="""#!/bin/bash
echo 'Starting process...'
# sleep 15
echo 'Hello, World!' > output.txt
cat output.txt
"""
)

# %%
process_hw.execute()
# Out:
# [2025-05-07 08:00:12] INFO:: [hello_world|d3a0] Executing process hello_world locally.
# [2025-05-07 08:00:12] INFO:: [hello_world|d3a0] Log folder for process hello_world: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/hello_world_20250507_080005_d3a0
# [2025-05-07 08:00:12] INFO:: [hello_world|d3a0] Preparing base script for process hello_world
# [2025-05-07 08:00:12] INFO:: [hello_world|d3a0] Process hello_world started with PID: 4186806
# [2025-05-07 08:00:12] INFO:: [hello_world|d3a0] Process hello_world (PID: 4186806) is still running...
# [2025-05-07 08:00:17] INFO:: [hello_world|d3a0] Process hello_world completed with exit code: 0

# %%
print(f"Process Name: {process_hw.name}")
print(f"Log Path: {process_hw.log_path}")
# Out:
# Process Name: hello_world
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/hello_world_20250507_080005_d3a0

# %%
### Python example
process_python = Process(
    name="python_example",
    script="""#!/usr/bin/env python3
print("Hello from Python")
print("2 + 2 =", 2 + 2)
""",
    retries=3
)

# %%
process_python.execute()
# Out:
# [2025-05-07 08:01:08] INFO:: [python_example|1e56] Executing process python_example locally.
# [2025-05-07 08:01:08] INFO:: [python_example|1e56] Log folder for process python_example: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/python_example_20250507_080101_1e56
# [2025-05-07 08:01:08] INFO:: [python_example|1e56] Preparing base script for process python_example
# [2025-05-07 08:01:08] INFO:: [python_example|1e56] Process python_example started with PID: 4187284
# [2025-05-07 08:01:08] INFO:: [python_example|1e56] Process python_example (PID: 4187284) is still running...
# [2025-05-07 08:01:13] INFO:: [python_example|1e56] Process python_example completed with exit code: 0

# %%
print(f"Log Path: {process_python.log_path}")
# Out:
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/python_example_20250507_080101_1e56

# %%
## R example
process_r = Process(
    name="r_example",
    script="""#!/usr/bin/env Rscript
cat("Hello from R\n")
print(2 + 2)
"""
)

# %%
process_r.execute()
# Out:
# [2025-05-07 08:01:47] INFO:: [r_example|f76a] Executing process r_example locally.
# [2025-05-07 08:01:47] INFO:: [r_example|f76a] Log folder for process r_example: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/r_example_20250507_080136_f76a
# [2025-05-07 08:01:47] INFO:: [r_example|f76a] Preparing base script for process r_example
# [2025-05-07 08:01:47] INFO:: [r_example|f76a] Process r_example started with PID: 4187425
# [2025-05-07 08:01:47] INFO:: [r_example|f76a] Process r_example (PID: 4187425) is still running...
# [2025-05-07 08:01:52] INFO:: [r_example|f76a] Process r_example completed with exit code: 0

# %%
print(f"Log Path: {process_r.log_path}")
# Out:
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/r_example_20250507_080136_f76a

# %%
# Run with script parameters
process_file = Process(
    name="python_file",
    script_file="scripts/hello.py",
    script_parameters={
        "APPNAME": "JAWM",
        "BYEMSG": "GOOD BYE!",
        "FRUITLIST": "['Apple', 'Banana', 'Orange']"
    }
)

# %%
process_file.execute()
# Out:
# [2025-05-07 08:03:11] INFO:: [python_file|4f7d] Executing process python_file locally.
# [2025-05-07 08:03:11] INFO:: [python_file|4f7d] Log folder for process python_file: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/python_file_20250507_080305_4f7d
# [2025-05-07 08:03:11] INFO:: [python_file|4f7d] Preparing base script for process python_file
# [2025-05-07 08:03:11] INFO:: [python_file|4f7d] Original script for process scripts/hello.py
# [2025-05-07 08:03:11] INFO:: [python_file|4f7d] Process python_file started with PID: 4187876
# [2025-05-07 08:03:11] INFO:: [python_file|4f7d] Process python_file (PID: 4187876) is still running...
# [2025-05-07 08:03:31] INFO:: [python_file|4f7d] Process python_file completed with exit code: 0

# %%
print(f"Log Path: {process_file.log_path}")
# Out:
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/python_file_20250507_080305_4f7d

# %%
# Run with script and parameters file
process_params = Process(
    name="python_file_params",
    script_file="scripts/hello.py",
    script_parameters_file="scripts/hello.rc"
)

# %%
process_params.execute()
# Out:
# [2025-05-07 08:04:52] INFO:: [python_file_params|e0e4] Executing process python_file_params locally.
# [2025-05-07 08:04:52] INFO:: [python_file_params|e0e4] Log folder for process python_file_params: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/python_file_params_20250507_080446_e0e4
# [2025-05-07 08:04:52] INFO:: [python_file_params|e0e4] Preparing base script for process python_file_params
# [2025-05-07 08:04:52] INFO:: [python_file_params|e0e4] Original script for process scripts/hello.py
# [2025-05-07 08:04:52] INFO:: [python_file_params|e0e4] Process python_file_params started with PID: 4188414
# [2025-05-07 08:04:52] INFO:: [python_file_params|e0e4] Process python_file_params (PID: 4188414) is still running...
# [2025-05-07 08:05:12] INFO:: [python_file_params|e0e4] Process python_file_params completed with exit code: 0

# %%
print(f"Log Path: {process_params.log_path}")
# Out:
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/python_file_params_20250507_080446_e0e4

# %%
process_skip = Process(
    name="python_file_params",
    script_file="scripts/hello.py",
    script_parameters_file="scripts/hello.rc",
    when=False
)

# %%
process_skip.execute()
# Out:
# [2025-05-07 08:05:45] INFO:: [python_file_params|fd67] Process python_file_params skipped because 'when' condition was not fulfilled!

# %%
# Run from paramters
process_c = Process(name="process_C", param_file=["parameters/metal.yaml", "parameters/metal2.yaml"])

# %%
process_c.execute()
# Out:
# [2025-05-07 08:11:47] INFO:: [process_C|5836] Executing process process_C locally.
# [2025-05-07 08:11:47] INFO:: [process_C|5836] Log folder for process process_C: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/process_C_20250507_081138_5836
# [2025-05-07 08:11:47] INFO:: [process_C|5836] Preparing base script for process process_C
# [2025-05-07 08:11:47] INFO:: [process_C|5836] Process process_C started with PID: 4191562
# [2025-05-07 08:11:47] INFO:: [process_C|5836] Process process_C (PID: 4191562) is still running...
# [2025-05-07 08:12:07] INFO:: [process_C|5836] Process process_C completed with exit code: 0

# %%
print(f"Log Path: {process_c.log_path}")
# Out:
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/process_C_20250507_081138_5836

# %%
# Run python with yaml parameter
process_py1 = Process(name="process_py1", param_file="parameters/python_example.yaml")
process_py2 = Process(name="process_py2", param_file="parameters/python_example.yaml")

# %%
process_py1.execute()
# Out:
# [2025-05-07 08:15:21] INFO:: [process_py1|babe] Executing process process_py1 locally.
# [2025-05-07 08:15:21] INFO:: [process_py1|babe] Log folder for process process_py1: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/process_py1_20250507_081503_babe
# [2025-05-07 08:15:21] INFO:: [process_py1|babe] Preparing base script for process process_py1
# [2025-05-07 08:15:21] INFO:: [process_py1|babe] Process process_py1 started with PID: 4193100
# [2025-05-07 08:15:21] INFO:: [process_py1|babe] Process process_py1 (PID: 4193100) is still running...
# [2025-05-07 08:15:26] INFO:: [process_py1|babe] Process process_py1 completed with exit code: 0

# %%
process_py2.execute()
# Out:
# [2025-05-07 08:15:42] INFO:: [process_py2|86eb] Executing process process_py2 locally.
# [2025-05-07 08:15:42] INFO:: [process_py2|86eb] Log folder for process process_py2: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/process_py2_20250507_081503_86eb
# [2025-05-07 08:15:42] INFO:: [process_py2|86eb] Preparing base script for process process_py2
# [2025-05-07 08:15:42] INFO:: [process_py2|86eb] Process process_py2 started with PID: 4193252
# [2025-05-07 08:15:42] INFO:: [process_py2|86eb] Process process_py2 (PID: 4193252) is still running...
# [2025-05-07 08:15:47] INFO:: [process_py2|86eb] Process process_py2 completed with exit code: 0

# %%
print(f"Log Path for {process_py1.name}: {process_py1.log_path}")
print(f"Log Path for {process_py2.name}: {process_py2.log_path}")
# Out:
# Log Path for process_py1: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/process_py1_20250507_081503_babe
# Log Path for process_py2: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/process_py2_20250507_081503_86eb

# %%
# Run with dependency
process_c = Process(name="process_C", param_file=["parameters/metal.yaml", "parameters/metal.yaml"])
process_c.execute()

process_a = Process(name="process_A", param_file="parameters/metal.yaml")
process_a.execute()

process_b = Process(name="process_B", param_file="parameters/metal.yaml")
process_b.execute()
# Out:
# [2025-05-07 08:17:49] INFO:: [process_C|76d4] Executing process process_C locally.
# [2025-05-07 08:17:49] INFO:: [process_C|76d4] Log folder for process process_C: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/process_C_20250507_081749_76d4
# [2025-05-07 08:17:49] INFO:: [process_C|76d4] Preparing base script for process process_C
# [2025-05-07 08:17:49] INFO:: [process_A|5f40] Waiting for dependency process process_C (76d4) to finish before executing process_A (5f40)
# [2025-05-07 08:17:49] INFO:: [process_C|76d4] Process process_C started with PID: 4194161
# [2025-05-07 08:17:49] INFO:: [process_C|76d4] Process process_C completed with exit code: 0
# [2025-05-07 08:17:49] INFO:: [process_A|5f40] Executing process process_A locally.
# [2025-05-07 08:17:49] INFO:: [process_A|5f40] Log folder for process process_A: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/process_A_20250507_081749_5f40
# [2025-05-07 08:17:49] INFO:: [process_A|5f40] Preparing base script for process process_A
# [2025-05-07 08:17:49] INFO:: [process_B|bd3c] Waiting for dependency process process_A (5f40) to finish before executing process_B (bd3c)
# [2025-05-07 08:17:49] INFO:: [process_A|5f40] Process process_A started with PID: 4194163
# [2025-05-07 08:17:49] INFO:: [process_A|5f40] Process process_A (PID: 4194163) is still running...
# [2025-05-07 08:17:59] INFO:: [process_A|5f40] Process process_A completed with exit code: 0
# [2025-05-07 08:17:59] INFO:: [process_B|bd3c] Executing process process_B locally.
# [2025-05-07 08:17:59] INFO:: [process_B|bd3c] Log folder for process process_B: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/process_B_20250507_081749_bd3c
# [2025-05-07 08:17:59] INFO:: [process_B|bd3c] Preparing base script for process process_B
# [2025-05-07 08:17:59] INFO:: [process_B|bd3c] Process process_B started with PID: 4194238
# [2025-05-07 08:17:59] INFO:: [process_B|bd3c] Process process_B (PID: 4194238) is still running...
# [2025-05-07 08:18:04] INFO:: [process_B|bd3c] Process process_B completed with exit code: 0

# %%
print(f"Log Path for {process_a.name}: {process_a.log_path}")
print(f"Log Path for {process_b.name}: {process_b.log_path}")
print(f"Log Path for {process_c.name}: {process_c.log_path}")
# Out:
# Log Path for process_A: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/process_A_20250507_081749_5f40
# Log Path for process_B: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/process_B_20250507_081749_bd3c
# Log Path for process_C: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/process_C_20250507_081749_76d4
