# %%
import sys
import os
import logging
import time
from jawm import Process

logging.basicConfig(level=logging.INFO)
os.environ['JAWM_MONITORING_DIRECTORY'] = 'monitoring'

# %%
### Hello World example
process_hw = Process(
    name="hello_world",
    script="""#!/bin/bash
echo 'Starting process...'
# sleep 15
echo 'Hello, World!' > output.txt
cat output.txt
"""
)

# %%
output = process_hw.execute()
# Out:
# INFO:hello_world:Executing process hello_world locally
# INFO:hello_world:Preparing base script for process hello_world
# INFO:hello_world:Process hello_world started with PID: 542666
# INFO:hello_world:Process hello_world completed with exit code: 0

# %%
print(f"Process/Job ID: {output}")
print(f"Log Path: {process_hw.log_path}")
# Out:
# Process/Job ID: 542666
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/hello_world_20250217_150111_metal_65

# %%
### Python example
process_python = Process(
    name="python_example",
    script="""#!/usr/bin/env python3
print("Hello from Python")
print("2 + 2 =", 2 + 2)
""",
    retries=3
)

# %%
output = process_python.execute()
# Out:
# INFO:python_example:Executing process python_example locally
# INFO:python_example:Preparing base script for process python_example
# INFO:python_example:Process python_example started with PID: 542894
# INFO:python_example:Process python_example completed with exit code: 0

# %%
print(f"Process/Job ID: {output}")
print(f"Log Path: {process_python.log_path}")
# Out:
# Process/Job ID: 542894
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/python_example_20250217_150137_metal_59

# %%
## R example
process_r = Process(
    name="r_example",
    script="""#!/usr/bin/env Rscript
cat("Hello from R\n")
print(2 + 2)
"""
)

# %%
output = process_r.execute()
# Out:
# INFO:r_example:Executing process r_example locally
# INFO:r_example:Preparing base script for process r_example
# INFO:r_example:Process r_example started with PID: 543012
# INFO:r_example:Process r_example completed with exit code: 0

# %%
print(f"Process/Job ID: {output}")
print(f"Log Path: {process_r.log_path}")
# Out:
# Process/Job ID: 543012
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/r_example_20250217_150151_metal_e8

# %%
# Run with script parameters
process_file = Process(
    name="python_file",
    script_file="scripts/hello.py",
    script_parameters={
        "APPNAME": "JAWM",
        "BYEMSG": "GOOD BYE!",
        "FRUITLIST": "['Apple', 'Banana', 'Orange']"
    }
)

# %%
output = process_file.execute()
# Out:
# INFO:python_file:Executing process python_file locally
# INFO:python_file:Preparing base script for process python_file
# INFO:python_file:Original script for process scripts/hello.py
# INFO:python_file:Process python_file started with PID: 543165
# INFO:python_file:Process python_file completed with exit code: 0

# %%
print(f"Process/Job ID: {output}")
print(f"Log Path: {process_file.log_path}")
# Out:
# Process/Job ID: 543165
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/python_file_20250217_150204_metal_ed

# %%
# Run with script and parameters file
process_params = Process(
    name="python_file_params",
    script_file="scripts/hello.py",
    script_parameters_file="scripts/hello.rc"
)

# %%
output = process_params.execute()
# Out:
# INFO:python_file_params:Executing process python_file_params locally
# INFO:python_file_params:Preparing base script for process python_file_params
# INFO:python_file_params:Original script for process scripts/hello.py
# INFO:python_file_params:Process python_file_params started with PID: 543437
# INFO:python_file_params:Process python_file_params completed with exit code: 0

# %%
print(f"Process/Job ID: {output}")
print(f"Log Path: {process_params.log_path}")
# Out:
# Process/Job ID: 543437
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/python_file_params_20250217_150232_metal_bc

# %%
process_skip = Process(
    name="python_file_params",
    script_file="scripts/hello.py",
    script_parameters_file="scripts/hello.rc",
    when=False
)

# %%
output = process_skip.execute()
# Out:
# INFO:python_file_params:Process python_file_params skipped as execution condition did not fulfilled!

# %%
# Run from paramters
process_c = Process(name="process_C", param_file=["parameters/metal.yaml", "parameters/metal2.yaml"])

# %%
output = process_c.execute()
# Out:
# INFO:process_C:Executing process process_C locally
# INFO:process_C:Preparing base script for process process_C
# INFO:process_C:Process process_C started with PID: 543734
# INFO:process_C:Process process_C completed with exit code: 0

# %%
print(f"Process/Job ID: {output}")
print(f"Log Path: {process_c.log_path}")
# Out:
# Process/Job ID: 543734
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/process_C_20250217_150302_metal_a9

# %%
# Run with dependency
process_c = Process(name="process_C", param_file=["parameters/metal.yaml", "parameters/metal.yaml"])
output_c = process_c.execute()

process_a = Process(name="process_A", param_file="parameters/metal.yaml")
output_a = process_a.execute()

process_b = Process(name="process_B", param_file="parameters/metal.yaml")
output_b = process_b.execute()
# Out:
# INFO:process_C:Executing process process_C locally
# INFO:process_C:Preparing base script for process process_C
# INFO:process_C:Process process_C started with PID: 540720
# INFO:process_C:Process process_C completed with exit code: 0
# INFO:process_A:Waiting for dependency process process_C to finish before executing process_A.
# INFO:process_A:Executing process process_A locally
# INFO:process_A:Preparing base script for process process_A
# INFO:process_A:Process process_A started with PID: 540722
# INFO:process_B:Waiting for dependency process process_A to finish before executing process_B.
# INFO:process_B:Executing process process_B locally
# INFO:process_B:Preparing base script for process process_B
# INFO:process_B:Process process_B started with PID: 540726
# INFO:process_B:Process process_B completed with exit code: 0
# INFO:process_A:Process process_A completed with exit code: 0

# %%
print(f"Process/Job ID: {output_a}")
print(f"Log Path: {process_a.log_path}")
print(f"Process/Job ID: {output_b}")
print(f"Log Path: {process_b.log_path}")
print(f"Process/Job ID: {output_c}")
print(f"Log Path: {process_c.log_path}")
# Out:
# Process/Job ID: 540722
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/process_A_20250217_145756_metal_22
# Process/Job ID: 540726
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/process_B_20250217_145756_metal_ca
# Process/Job ID: 540720
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs/process_C_20250217_145755_metal_a9
