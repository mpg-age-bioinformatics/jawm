# %%
import os
os.environ['JAWM_MONITORING_DIRECTORY'] = 'monitoring'

# For development
# import sys
# sys.path.append(os.path.abspath(os.path.join(os.path.abspath(os.getcwd()), '..')))

from jawm import Process

# %%
### Hello World example
process_hw = Process(
    name="hello_world",
    script="""#!/bin/bash
echo 'Starting process...'
echo 'Hello World from Slurm!' > output_slurm.txt
cat output_slurm.txt
""",
    manager="slurm",
    manager_slurm={"partition":"dedicated"},
    logs_directory="logs_slurm"
)

# %%
# Get any paramters
process_hw.logs_directory
# Out:
# '/nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm'

# %%
process_hw.execute()
# Out:
# [2025-05-07 08:38:34] INFO:: [hello_world|7aee] Executing process hello_world in Slurm
# [2025-05-07 08:38:34] INFO:: [hello_world|7aee] Log folder for process hello_world: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/hello_world_20250507_083822_7aee
# [2025-05-07 08:38:34] INFO:: [hello_world|7aee] Generating Slurm job script for process: hello_world
# [2025-05-07 08:38:34] INFO:: [hello_world|7aee] Preparing base script for process hello_world
# [2025-05-07 08:38:34] INFO:: [hello_world|7aee] Submitting process hello_world with slurm command: sbatch --partition dedicated --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/hello_world_20250507_083822_7aee/hello_world.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/hello_world_20250507_083822_7aee/hello_world.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/hello_world_20250507_083822_7aee/hello_world.slurm
# [2025-05-07 08:38:44] INFO:: [hello_world|7aee] Process hello_world submitted as Slurm job 526152.
# [2025-05-07 08:38:54] INFO:: [hello_world|7aee] Slurm job 526152 completed with exit code: 0:0

# %%
print(f"Log Path: {process_hw.log_path}")
# Out:
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/hello_world_20250507_083822_7aee

# %%
### Hello World failed example
process_hw = Process(
    name="hello_world",
    script="""#!/bin/bash
echo 'Hello World Failed!' > output.txt
echoooooo 'ENding process...'
""",
    manager="slurm",
    manager_slurm={"partition":"dedicated", "mem":"1GB"},
    logs_directory="logs_slurm"
)

# %%
process_hw.execute()
# Out:
# [2025-05-07 08:39:29] INFO:: [hello_world|a64a] Executing process hello_world in Slurm
# [2025-05-07 08:39:29] INFO:: [hello_world|a64a] Log folder for process hello_world: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/hello_world_20250507_083924_a64a
# [2025-05-07 08:39:29] INFO:: [hello_world|a64a] Generating Slurm job script for process: hello_world
# [2025-05-07 08:39:29] INFO:: [hello_world|a64a] Preparing base script for process hello_world
# [2025-05-07 08:39:29] INFO:: [hello_world|a64a] Submitting process hello_world with slurm command: sbatch --partition dedicated --mem 1GB --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/hello_world_20250507_083924_a64a/hello_world.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/hello_world_20250507_083924_a64a/hello_world.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/hello_world_20250507_083924_a64a/hello_world.slurm
# [2025-05-07 08:39:39] INFO:: [hello_world|a64a] Process hello_world submitted as Slurm job 526153.
# [2025-05-07 08:39:49] INFO:: [hello_world|a64a] Slurm job 526153 completed with exit code: 127:0
# [2025-05-07 08:39:49] ERROR:: [hello_world|a64a] Attempt 1 for process hello_world failed in Slurm
# Exception in thread Thread-6 (monitor_process):
# Traceback (most recent call last):
#   File "/opt/python/3.12.6/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/opt/python/3.12.6/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/opt/python/3.12.6/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/nexus/posix0/MAGE-flaski/service/posit/home/hamin/.jupyter/python/3.12/lib/python3.12/site-packages/jawm/_process_slurm.py", line 202, in monitor_process
#     raise RuntimeError(f"Process {self.name} in Slurm failed after {total_attempts} attempts.")
# RuntimeError: Process hello_world in Slurm failed after 1 attempts.

# %%
print(f"Log Path: {process_hw.log_path}")
# Out:
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/hello_world_20250507_083924_a64a

# %%
# Reset stop_future_event to execute in the same script neglecting the last error
Process.stop_future_event.clear()

# %%
### Python example
process_python = Process(
    name="python_example",
    script="""#!/usr/bin/env python3
print("Hello from Python")
print("2 + 2 =", 2 + 2)
""",
    retries=3,
    manager="slurm",
    manager_slurm={"partition":"dedicated", "mem":"1GB"},
    logs_directory="logs_slurm"
)

# %%
process_python.execute()
# Out:
# [2025-05-07 08:41:42] INFO:: [python_example|d5a8] Executing process python_example in Slurm
# [2025-05-07 08:41:42] INFO:: [python_example|d5a8] Log folder for process python_example: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_example_20250507_084136_d5a8
# [2025-05-07 08:41:42] INFO:: [python_example|d5a8] Generating Slurm job script for process: python_example
# [2025-05-07 08:41:42] INFO:: [python_example|d5a8] Preparing base script for process python_example
# [2025-05-07 08:41:42] INFO:: [python_example|d5a8] Submitting process python_example with slurm command: sbatch --partition dedicated --mem 1GB --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_example_20250507_084136_d5a8/python_example.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_example_20250507_084136_d5a8/python_example.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_example_20250507_084136_d5a8/python_example.slurm
# [2025-05-07 08:41:52] INFO:: [python_example|d5a8] Process python_example submitted as Slurm job 526154.
# [2025-05-07 08:42:02] INFO:: [python_example|d5a8] Slurm job 526154 completed with exit code: 0:0

# %%
print(f"Log Path: {process_python.log_path}")
# Out:
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_example_20250507_084136_d5a8

# %%
## R example
process_r = Process(
    name="r_example",
    script="""#!/usr/bin/env Rscript
cat("Hello from R\n")
print(2 + 2)
""",
    retries=3,
    manager="slurm",
    manager_slurm={"partition":"cluster", "mem":"2GB"},
    logs_directory="logs_slurm"
)

# %%
process_r.execute()
# Out:
# [2025-05-07 08:43:09] INFO:: [r_example|1fb7] Executing process r_example in Slurm
# [2025-05-07 08:43:09] INFO:: [r_example|1fb7] Log folder for process r_example: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/r_example_20250507_084303_1fb7
# [2025-05-07 08:43:09] INFO:: [r_example|1fb7] Generating Slurm job script for process: r_example
# [2025-05-07 08:43:09] INFO:: [r_example|1fb7] Preparing base script for process r_example
# [2025-05-07 08:43:09] INFO:: [r_example|1fb7] Submitting process r_example with slurm command: sbatch --partition cluster --mem 2GB --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/r_example_20250507_084303_1fb7/r_example.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/r_example_20250507_084303_1fb7/r_example.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/r_example_20250507_084303_1fb7/r_example.slurm
# [2025-05-07 08:43:19] INFO:: [r_example|1fb7] Process r_example submitted as Slurm job 526155.
# [2025-05-07 08:43:29] INFO:: [r_example|1fb7] Slurm job 526155 completed with exit code: 127:0
# [2025-05-07 08:43:29] ERROR:: [r_example|1fb7] Attempt 1 for process r_example failed in Slurm
# [2025-05-07 08:43:29] INFO:: [r_example|1fb7] Retrying process r_example in Slurm, 3 retries left
# [2025-05-07 08:43:29] INFO:: [r_example|1fb7] Launching Slurm attempt 2/4 for r_example...
# [2025-05-07 08:43:29] INFO:: [r_example|1fb7] Generating Slurm job script for process: r_example
# [2025-05-07 08:43:29] INFO:: [r_example|1fb7] Submitting process r_example with slurm command: sbatch --partition cluster --mem 2GB --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/r_example_20250507_084303_1fb7/r_example.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/r_example_20250507_084303_1fb7/r_example.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/r_example_20250507_084303_1fb7/r_example.slurm
# [2025-05-07 08:43:39] INFO:: [r_example|1fb7] Process r_example submitted as Slurm job 526156.
# [2025-05-07 08:43:49] INFO:: [r_example|1fb7] Slurm job 526156 completed with exit code: 127:0
# [2025-05-07 08:43:49] ERROR:: [r_example|1fb7] Attempt 2 for process r_example failed in Slurm
# [2025-05-07 08:43:49] INFO:: [r_example|1fb7] Retrying process r_example in Slurm, 2 retries left
# [2025-05-07 08:43:49] INFO:: [r_example|1fb7] Launching Slurm attempt 3/4 for r_example...
# [2025-05-07 08:43:49] INFO:: [r_example|1fb7] Generating Slurm job script for process: r_example
# [2025-05-07 08:43:49] INFO:: [r_example|1fb7] Submitting process r_example with slurm command: sbatch --partition cluster --mem 2GB --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/r_example_20250507_084303_1fb7/r_example.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/r_example_20250507_084303_1fb7/r_example.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/r_example_20250507_084303_1fb7/r_example.slurm
# [2025-05-07 08:43:59] INFO:: [r_example|1fb7] Process r_example submitted as Slurm job 526157.
# [2025-05-07 08:44:09] INFO:: [r_example|1fb7] Slurm job 526157 completed with exit code: 127:0
# [2025-05-07 08:44:09] ERROR:: [r_example|1fb7] Attempt 3 for process r_example failed in Slurm
# [2025-05-07 08:44:09] INFO:: [r_example|1fb7] Retrying process r_example in Slurm, 1 retries left
# [2025-05-07 08:44:09] INFO:: [r_example|1fb7] Launching Slurm attempt 4/4 for r_example...
# [2025-05-07 08:44:09] INFO:: [r_example|1fb7] Generating Slurm job script for process: r_example
# [2025-05-07 08:44:10] INFO:: [r_example|1fb7] Submitting process r_example with slurm command: sbatch --partition cluster --mem 2GB --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/r_example_20250507_084303_1fb7/r_example.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/r_example_20250507_084303_1fb7/r_example.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/r_example_20250507_084303_1fb7/r_example.slurm
# [2025-05-07 08:44:20] INFO:: [r_example|1fb7] Process r_example submitted as Slurm job 526158.
# [2025-05-07 08:44:30] INFO:: [r_example|1fb7] Slurm job 526158 completed with exit code: 127:0
# [2025-05-07 08:44:30] ERROR:: [r_example|1fb7] Attempt 4 for process r_example failed in Slurm
# Exception in thread Thread-8 (monitor_process):
# Traceback (most recent call last):
#   File "/opt/python/3.12.6/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/opt/python/3.12.6/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/opt/python/3.12.6/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/nexus/posix0/MAGE-flaski/service/posit/home/hamin/.jupyter/python/3.12/lib/python3.12/site-packages/jawm/_process_slurm.py", line 202, in monitor_process
#     raise RuntimeError(f"Process {self.name} in Slurm failed after {total_attempts} attempts.")
# RuntimeError: Process r_example in Slurm failed after 4 attempts.

# %%
print(f"Log Path: {process_r.log_path}")
print(f"Error Summary Log: {process_r.error_summary_file}")
# Out:
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/r_example_20250507_084303_1fb7
# Error Summary Log: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/error_summary.log

# %%
# process_r failed due to the absence of R in the system
# Error can be checked easily from the `error_summary_file` or `log_path`
# Got error "Error: /usr/bin/env: ‘Rscript’: No such file or directory"
Process.stop_future_event.clear()

# %%
## R example
process_r_apptainer = Process(
    name="r_example",
    script="""#!/usr/bin/env Rscript
cat("Hello from R\n")
print(2 + 2)
""",
    retries=3,
    manager="slurm",
    manager_slurm={"partition":"cluster", "mem":"2GB"},
    logs_directory="logs_slurm",
    environment='apptainer',
    container="/nexus/posix0/MAGE-flaski/service/images/posit-latest.sif",    
)

# %%
process_r_apptainer.execute()
# Out:
# [2025-05-07 09:03:26] INFO:: [r_example|8027] Executing process r_example in Slurm
# [2025-05-07 09:03:26] INFO:: [r_example|8027] Log folder for process r_example: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/r_example_20250507_090305_8027
# [2025-05-07 09:03:26] INFO:: [r_example|8027] Generating Slurm job script for process: r_example
# [2025-05-07 09:03:26] INFO:: [r_example|8027] Preparing base script for process r_example
# [2025-05-07 09:03:26] INFO:: [r_example|8027] Submitting process r_example with slurm command: sbatch --partition cluster --mem 2GB --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/r_example_20250507_090305_8027/r_example.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/r_example_20250507_090305_8027/r_example.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/r_example_20250507_090305_8027/r_example.slurm
# [2025-05-07 09:03:36] INFO:: [r_example|8027] Process r_example submitted as Slurm job 526159.
# [2025-05-07 09:03:46] INFO:: [r_example|8027] Slurm job 526159 completed with exit code: 0:0

# %%
print(f"Log Path: {process_r_apptainer.log_path}")
# Out:
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/r_example_20250507_090305_8027

# %%
# Run with script parameters
process_file = Process(
    name="python_file",
    script_file="scripts/hello.py",
    script_parameters={
        "APPNAME": "JAWM",
        "BYEMSG": "GOOD BYE!",
        "FRUITLIST": "['Apple', 'Banana', 'Orange']"
    },
    retries=3,
    manager="slurm",
    manager_slurm={"partition":"cluster", "mem":"2GB"},
    logs_directory="logs_slurm"
)

# %%
# Check the provided params
process_file.params
# Out:
# {'script_file': 'scripts/hello.py',
#  'script_parameters': {'APPNAME': 'JAWM',
#   'BYEMSG': 'GOOD BYE!',
#   'FRUITLIST': "['Apple', 'Banana', 'Orange']"},
#  'retries': 3,
#  'manager': 'slurm',
#  'manager_slurm': {'partition': 'cluster', 'mem': '2GB'},
#  'logs_directory': 'logs_slurm'}

# %%
process_file.execute()
# Out:
# [2025-05-07 09:51:16] INFO:: [python_file|7047] Executing process python_file in Slurm
# [2025-05-07 09:51:16] INFO:: [python_file|7047] Log folder for process python_file: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_file_20250507_095102_7047
# [2025-05-07 09:51:16] INFO:: [python_file|7047] Generating Slurm job script for process: python_file
# [2025-05-07 09:51:16] INFO:: [python_file|7047] Preparing base script for process python_file
# [2025-05-07 09:51:16] INFO:: [python_file|7047] Original script for process scripts/hello.py
# [2025-05-07 09:51:16] INFO:: [python_file|7047] Submitting process python_file with slurm command: sbatch --partition cluster --mem 2GB --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_file_20250507_095102_7047/python_file.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_file_20250507_095102_7047/python_file.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_file_20250507_095102_7047/python_file.slurm
# [2025-05-07 09:51:26] INFO:: [python_file|7047] Process python_file submitted as Slurm job 526205.
# [2025-05-07 09:51:26] INFO:: [python_file|7047] Slurm job 526205 state=PENDING, exit_code=0:0
# [2025-05-07 09:51:46] INFO:: [python_file|7047] Slurm job 526205 completed with exit code: 0:0

# %%
print(f"Log Path: {process_file.log_path}")
# Out:
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_file_20250507_095102_7047

# %%
# Run with script and parameters file
process_params = Process(
    name="python_file_params",
    script_file="scripts/hello.py",
    script_parameters_file="scripts/hello.rc",
    manager="slurm",
    manager_slurm={"partition":"cluster", "mem":"2GB"},
    logs_directory="logs_slurm"
)

# %%
process_params.execute()
# Out:
# [2025-05-07 09:52:20] INFO:: [python_file_params|9b62] Executing process python_file_params in Slurm
# [2025-05-07 09:52:20] INFO:: [python_file_params|9b62] Log folder for process python_file_params: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_file_params_20250507_095205_9b62
# [2025-05-07 09:52:20] INFO:: [python_file_params|9b62] Generating Slurm job script for process: python_file_params
# [2025-05-07 09:52:20] INFO:: [python_file_params|9b62] Preparing base script for process python_file_params
# [2025-05-07 09:52:20] INFO:: [python_file_params|9b62] Original script for process scripts/hello.py
# [2025-05-07 09:52:20] INFO:: [python_file_params|9b62] Submitting process python_file_params with slurm command: sbatch --partition cluster --mem 2GB --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_file_params_20250507_095205_9b62/python_file_params.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_file_params_20250507_095205_9b62/python_file_params.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_file_params_20250507_095205_9b62/python_file_params.slurm
# [2025-05-07 09:52:30] INFO:: [python_file_params|9b62] Process python_file_params submitted as Slurm job 526206.
# [2025-05-07 09:52:51] INFO:: [python_file_params|9b62] Slurm job 526206 completed with exit code: 0:0

# %%
print(f"Log Path: {process_params.log_path}")
# Out:
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_file_params_20250507_095205_9b62

# %%
process_skip = Process(
    name="python_file_params",
    script_file="scripts/hello.py",
    script_parameters_file="scripts/hello.rc",
    when=False,
    manager="slurm",
    manager_slurm={"partition":"cluster", "mem":"2GB"},
    logs_directory="logs_slurm"
)

# %%
process_skip.execute()
# Out:
# [2025-05-07 09:53:04] INFO:: [python_file_params|9a85] Process python_file_params skipped because 'when' condition was not fulfilled!

# %%
print(f"Log Path: {process_skip.log_path}")
# Out:
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_file_params_20250507_095258_9a85

# %%
# Run from paramters
process_c = Process(name="process_C", param_file=["parameters/slurm.yaml", "parameters/slurm2.yaml"])

# %%
process_c.execute()
# Out:
# [2025-05-07 09:53:33] INFO:: [process_C|a3c8] Executing process process_C in Slurm
# [2025-05-07 09:53:33] INFO:: [process_C|a3c8] Log folder for process process_C: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_C_20250507_095330_a3c8
# [2025-05-07 09:53:33] INFO:: [process_C|a3c8] Generating Slurm job script for process: process_C
# [2025-05-07 09:53:33] INFO:: [process_C|a3c8] Preparing base script for process process_C
# [2025-05-07 09:53:33] INFO:: [process_C|a3c8] Submitting process process_C with slurm command: sbatch --partition cluster --mem 2GB --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_C_20250507_095330_a3c8/process_C.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_C_20250507_095330_a3c8/process_C.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_C_20250507_095330_a3c8/process_C.slurm
# [2025-05-07 09:53:43] INFO:: [process_C|a3c8] Process process_C submitted as Slurm job 526207.
# [2025-05-07 09:54:04] INFO:: [process_C|a3c8] Slurm job 526207 completed with exit code: 0:0

# %%
print(f"Log Path: {process_c.log_path}")
# Out:
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_C_20250507_095330_a3c8

# %%
# Run with dependency
process_c = Process(name="process_C", param_file=["parameters/slurm.yaml", "parameters/slurm2.yaml"])
process_c.execute()

process_a = Process(name="process_A", param_file="parameters/slurm.yaml")
process_a.execute()

process_b = Process(name="process_B", param_file="parameters/slurm.yaml")
process_b.execute()
# Out:
# [2025-05-07 09:54:55] INFO:: [process_C|2994] Executing process process_C in Slurm
# [2025-05-07 09:54:55] INFO:: [process_C|2994] Log folder for process process_C: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_C_20250507_095455_2994
# [2025-05-07 09:54:55] INFO:: [process_C|2994] Generating Slurm job script for process: process_C
# [2025-05-07 09:54:55] INFO:: [process_C|2994] Preparing base script for process process_C
# [2025-05-07 09:54:55] INFO:: [process_A|90be] Waiting for dependency process process_C (2994) to finish before executing process_A (90be)
# [2025-05-07 09:54:55] INFO:: [process_C|2994] Submitting process process_C with slurm command: sbatch --partition cluster --mem 2GB --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_C_20250507_095455_2994/process_C.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_C_20250507_095455_2994/process_C.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_C_20250507_095455_2994/process_C.slurm
# [2025-05-07 09:55:05] INFO:: [process_C|2994] Process process_C submitted as Slurm job 526208.
# [2025-05-07 09:55:25] INFO:: [process_C|2994] Slurm job 526208 completed with exit code: 0:0
# [2025-05-07 09:55:25] INFO:: [process_A|90be] Executing process process_A in Slurm
# [2025-05-07 09:55:25] INFO:: [process_A|90be] Log folder for process process_A: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_A_20250507_095455_90be
# [2025-05-07 09:55:25] INFO:: [process_A|90be] Generating Slurm job script for process: process_A
# [2025-05-07 09:55:25] INFO:: [process_A|90be] Preparing base script for process process_A
# [2025-05-07 09:55:25] INFO:: [process_B|5766] Waiting for dependency process process_A (90be) to finish before executing process_B (5766)
# [2025-05-07 09:55:25] INFO:: [process_A|90be] Submitting process process_A with slurm command: sbatch --partition cluster --mem 2GB --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_A_20250507_095455_90be/process_A.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_A_20250507_095455_90be/process_A.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_A_20250507_095455_90be/process_A.slurm
# [2025-05-07 09:55:35] INFO:: [process_A|90be] Process process_A submitted as Slurm job 526209.
# [2025-05-07 09:57:46] INFO:: [process_A|90be] Slurm job 526209 completed with exit code: 0:0
# [2025-05-07 09:57:46] INFO:: [process_B|5766] Executing process process_B in Slurm
# [2025-05-07 09:57:46] INFO:: [process_B|5766] Log folder for process process_B: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_B_20250507_095525_5766
# [2025-05-07 09:57:46] INFO:: [process_B|5766] Generating Slurm job script for process: process_B
# [2025-05-07 09:57:46] INFO:: [process_B|5766] Preparing base script for process process_B
# [2025-05-07 09:57:46] INFO:: [process_B|5766] Submitting process process_B with slurm command: sbatch --partition cluster --mem 2GB --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_B_20250507_095525_5766/process_B.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_B_20250507_095525_5766/process_B.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_B_20250507_095525_5766/process_B.slurm
# [2025-05-07 09:57:56] INFO:: [process_B|5766] Process process_B submitted as Slurm job 526210.
# [2025-05-07 09:59:07] INFO:: [process_B|5766] Slurm job 526210 completed with exit code: 0:0

# %%
print(f"Log Path of {process_a.name}: {process_a.log_path}")
print(f"Log Path of {process_b.name}: {process_b.log_path}")
print(f"Log Path of {process_c.name}: {process_c.log_path}")
# Out:
# Log Path of process_A: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_A_20250507_095455_90be
# Log Path of process_B: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_B_20250507_095525_5766
# Log Path of process_C: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_C_20250507_095455_2994

# %%
# Run with apptainer container
process_apptainer = Process(
    name="slurm_apptainer",
    script="""#!/bin/bash
echo $HOSTNAME
echo $MY_VAR
""",
    environment='apptainer',
    container="/nexus/posix0/MAGE-flaski/service/images/python.sif",
    # environment_apptainer={
    #     "bind": ["/path/abc/:/abc/", "/path/def/:/def/"],
    #     "home": "/path/home"
    # },
    env={
        "MY_VAR": "APP_Value",
        "ANOTHER_VAR": "ANOTHER_VAR"
    },
    manager="slurm",
    manager_slurm={"partition":"dedicated", "mem":"4G"},
    logs_directory="logs_slurm"
)

# %%
process_apptainer.execute()
# Out:
# [2025-05-07 09:59:32] INFO:: [slurm_apptainer|181b] Executing process slurm_apptainer in Slurm
# [2025-05-07 09:59:32] INFO:: [slurm_apptainer|181b] Log folder for process slurm_apptainer: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/slurm_apptainer_20250507_095927_181b
# [2025-05-07 09:59:32] INFO:: [slurm_apptainer|181b] Generating Slurm job script for process: slurm_apptainer
# [2025-05-07 09:59:32] INFO:: [slurm_apptainer|181b] Preparing base script for process slurm_apptainer
# [2025-05-07 09:59:32] INFO:: [slurm_apptainer|181b] Submitting process slurm_apptainer with slurm command: sbatch --partition dedicated --mem 4G --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/slurm_apptainer_20250507_095927_181b/slurm_apptainer.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/slurm_apptainer_20250507_095927_181b/slurm_apptainer.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/slurm_apptainer_20250507_095927_181b/slurm_apptainer.slurm
# [2025-05-07 09:59:42] INFO:: [slurm_apptainer|181b] Process slurm_apptainer submitted as Slurm job 526243.
# [2025-05-07 10:00:03] INFO:: [slurm_apptainer|181b] Slurm job 526243 completed with exit code: 0:0

# %%
print(f"Log Path: {process_apptainer.log_path}")
# Out:
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/slurm_apptainer_20250507_095927_181b

# %%
# Run with singularity container from parameter file
singularity_params = Process(name="singularity_params", param_file=["parameters/slurm.yaml", "parameters/slurm2.yaml"])
singularity_params.execute()
# Out:
# [2025-05-07 10:00:11] INFO:: [singularity_params|640b] Executing process singularity_params in Slurm
# [2025-05-07 10:00:11] INFO:: [singularity_params|640b] Log folder for process singularity_params: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/singularity_params_20250507_100011_640b
# [2025-05-07 10:00:11] INFO:: [singularity_params|640b] Generating Slurm job script for process: singularity_params
# [2025-05-07 10:00:11] INFO:: [singularity_params|640b] Preparing base script for process singularity_params
# [2025-05-07 10:00:11] INFO:: [singularity_params|640b] Submitting process singularity_params with slurm command: sbatch --partition cluster --mem 2GB --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/singularity_params_20250507_100011_640b/singularity_params.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/singularity_params_20250507_100011_640b/singularity_params.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/singularity_params_20250507_100011_640b/singularity_params.slurm
# [2025-05-07 10:00:16] INFO:: [singularity_params|640b] Process singularity_params submitted as Slurm job 526244.
# [2025-05-07 10:00:36] INFO:: [singularity_params|640b] Slurm job 526244 completed with exit code: 0:0

# %%
print(f"Log Path: {singularity_params.log_path}")
# Out:
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/singularity_params_20250507_100011_640b
