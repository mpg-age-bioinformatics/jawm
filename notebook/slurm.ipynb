# %%
import sys
import os
import logging
import time
from jawm import Process

logging.basicConfig(level=logging.INFO)
os.environ['JAWM_MONITORING_DIRECTORY'] = 'monitoring'

# %%
### Hello World example
process_hw = Process(
    name="hello_world",
    script="""#!/bin/bash
echo 'Starting process...'
echo 'Hello World from Slurm!' > output.txt
cat output.txt
""",
    manager="slurm",
    manager_slurm={"partition":"dedicated"},
    logs_directory="logs_slurm"
)

# %%
# Get any paramters
process_hw.logs_directory
# Out:
# '/nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm'

# %%
output = process_hw.execute()
# Out:
# INFO:hello_world:Executing process hello_world in Slurm
# INFO:hello_world:Log folder for process hello_world: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/hello_world_20250218_142215_slurm_fe
# INFO:hello_world:Generating Slurm job script for process: hello_world
# INFO:hello_world:Preparing base script for process hello_world
# INFO:hello_world:Submitting process hello_world with command: sbatch --partition dedicated --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/hello_world_20250218_142215_slurm_fe/hello_world.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/hello_world_20250218_142215_slurm_fe/hello_world.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/hello_world_20250218_142215_slurm_fe/hello_world.slurm
# INFO:hello_world:Process hello_world submitted as Slurm job 489504.
# INFO:hello_world:Job 489504 completed with exit code: 0:0

# %%
print(f"Process/Job ID: {output}")
print(f"Log Path: {process_hw.log_path}")
# Out:
# Process/Job ID: 489504
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/hello_world_20250218_142215_slurm_fe

# %%
### Hello World failed example
process_hw = Process(
    name="hello_world",
    script="""#!/bin/bash
echo 'Hello World Failed!' > output.txt
echoooooo 'ENding process...'
""",
    manager="slurm",
    manager_slurm={"partition":"dedicated", "mem":"1GB"},
    logs_directory="logs_slurm"
)

# %%
output = process_hw.execute()
# Out:
# INFO:hello_world:Executing process hello_world in Slurm
# INFO:hello_world:Log folder for process hello_world: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/hello_world_20250218_142315_slurm_ee
# INFO:hello_world:Generating Slurm job script for process: hello_world
# INFO:hello_world:Preparing base script for process hello_world
# INFO:hello_world:Submitting process hello_world with command: sbatch --partition dedicated --mem 1GB --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/hello_world_20250218_142315_slurm_ee/hello_world.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/hello_world_20250218_142315_slurm_ee/hello_world.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/hello_world_20250218_142315_slurm_ee/hello_world.slurm
# INFO:hello_world:Process hello_world submitted as Slurm job 489505.
# INFO:hello_world:Job 489505 completed with exit code: 127:0

# %%
print(f"Process/Job ID: {output}")
print(f"Log Path: {process_hw.log_path}")
# Out:
# Process/Job ID: 489505
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/hello_world_20250218_142315_slurm_ee

# %%
### Python example
process_python = Process(
    name="python_example",
    script="""#!/usr/bin/env python3
print("Hello from Python")
print("2 + 2 =", 2 + 2)
""",
    retries=3,
    manager="slurm",
    manager_slurm={"partition":"dedicated", "mem":"1GB"},
    logs_directory="logs_slurm"
)

# %%
output = process_python.execute()
# Out:
# INFO:python_example:Executing process python_example in Slurm
# INFO:python_example:Log folder for process python_example: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_example_20250218_142451_slurm_d7
# INFO:python_example:Generating Slurm job script for process: python_example
# INFO:python_example:Preparing base script for process python_example
# INFO:python_example:Submitting process python_example with command: sbatch --partition dedicated --mem 1GB --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_example_20250218_142451_slurm_d7/python_example.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_example_20250218_142451_slurm_d7/python_example.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_example_20250218_142451_slurm_d7/python_example.slurm
# INFO:python_example:Process python_example submitted as Slurm job 489506.
# INFO:python_example:Job 489506 completed with exit code: 0:0

# %%
print(f"Process/Job ID: {output}")
print(f"Log Path: {process_python.log_path}")
# Out:
# Process/Job ID: 489506
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_example_20250218_142451_slurm_d7

# %%
## R example
process_r = Process(
    name="r_example",
    script="""#!/usr/bin/env Rscript
cat("Hello from R\n")
print(2 + 2)
""",
    retries=3,
    manager="slurm",
    manager_slurm={"partition":"cluster", "mem":"2GB"},
    logs_directory="logs_slurm"
)

# %%
output = process_r.execute()
# Out:
# INFO:r_example:Executing process r_example in Slurm
# INFO:r_example:Log folder for process r_example: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/r_example_20250218_142553_slurm_cb
# INFO:r_example:Generating Slurm job script for process: r_example
# INFO:r_example:Preparing base script for process r_example
# INFO:r_example:Submitting process r_example with command: sbatch --partition cluster --mem 2GB --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/r_example_20250218_142553_slurm_cb/r_example.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/r_example_20250218_142553_slurm_cb/r_example.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/r_example_20250218_142553_slurm_cb/r_example.slurm
# INFO:r_example:Process r_example submitted as Slurm job 489507.
# INFO:r_example:Job 489507 completed with exit code: 127:0

# %%
print(f"Process/Job ID: {output}")
print(f"Log Path: {process_r.log_path}")
# Out:
# Process/Job ID: 489507
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/r_example_20250218_142553_slurm_cb

# %%
# Run with script parameters
process_file = Process(
    name="python_file",
    script_file="scripts/hello.py",
    script_parameters={
        "APPNAME": "JAWM",
        "BYEMSG": "GOOD BYE!",
        "FRUITLIST": "['Apple', 'Banana', 'Orange']"
    },
    retries=3,
    manager="slurm",
    manager_slurm={"partition":"cluster", "mem":"2GB"},
    logs_directory="logs_slurm"
)

# %%
# Check the provided params
process_file.params
# Out:
# {'script_file': 'scripts/hello.py',
#  'script_parameters': {'APPNAME': 'JAWM',
#   'BYEMSG': 'GOOD BYE!',
#   'FRUITLIST': "['Apple', 'Banana', 'Orange']"},
#  'retries': 3,
#  'manager': 'slurm',
#  'manager_slurm': {'partition': 'cluster', 'mem': '2GB'},
#  'logs_directory': 'logs_slurm'}

# %%
output = process_file.execute()
# Out:
# INFO:python_file:Executing process python_file in Slurm
# INFO:python_file:Log folder for process python_file: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_file_20250218_142715_slurm_96
# INFO:python_file:Generating Slurm job script for process: python_file
# INFO:python_file:Preparing base script for process python_file
# INFO:python_file:Original script for process scripts/hello.py
# INFO:python_file:Submitting process python_file with command: sbatch --partition cluster --mem 2GB --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_file_20250218_142715_slurm_96/python_file.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_file_20250218_142715_slurm_96/python_file.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_file_20250218_142715_slurm_96/python_file.slurm
# INFO:python_file:Process python_file submitted as Slurm job 489508.
# INFO:python_file:Job 489508 completed with exit code: 0:0

# %%
print(f"Process/Job ID: {output}")
print(f"Log Path: {process_file.log_path}")
# Out:
# Process/Job ID: 489508
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_file_20250218_142715_slurm_96

# %%
# Run with script and parameters file
process_params = Process(
    name="python_file_params",
    script_file="scripts/hello.py",
    script_parameters_file="scripts/hello.rc",
    manager="slurm",
    manager_slurm={"partition":"cluster", "mem":"2GB"},
    logs_directory="logs_slurm"
)

# %%
output = process_params.execute()
# Out:
# INFO:python_file_params:Executing process python_file_params in Slurm
# INFO:python_file_params:Log folder for process python_file_params: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_file_params_20250218_142936_slurm_34
# INFO:python_file_params:Generating Slurm job script for process: python_file_params
# INFO:python_file_params:Preparing base script for process python_file_params
# INFO:python_file_params:Original script for process scripts/hello.py
# INFO:python_file_params:Submitting process python_file_params with command: sbatch --partition cluster --mem 2GB --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_file_params_20250218_142936_slurm_34/python_file_params.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_file_params_20250218_142936_slurm_34/python_file_params.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_file_params_20250218_142936_slurm_34/python_file_params.slurm
# INFO:python_file_params:Process python_file_params submitted as Slurm job 489509.
# INFO:python_file_params:Job 489509 completed with exit code: 0:0

# %%
print(f"Process/Job ID: {output}")
print(f"Log Path: {process_params.log_path}")
# Out:
# Process/Job ID: 489509
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/python_file_params_20250218_142936_slurm_34

# %%
process_skip = Process(
    name="python_file_params",
    script_file="scripts/hello.py",
    script_parameters_file="scripts/hello.rc",
    when=False,
    manager="slurm",
    manager_slurm={"partition":"cluster", "mem":"2GB"},
    logs_directory="logs_slurm"
)

# %%
output = process_skip.execute()
# Out:
# INFO:python_file_params:Process python_file_params skipped as execution condition did not fulfilled!

# %%
print(f"Process/Job ID: {output}")
# Out:
# Process/Job ID: None

# %%
# Run from paramters
process_c = Process(name="process_C", param_file=["parameters/slurm.yaml", "parameters/slurm2.yaml"])

# %%
output = process_c.execute()
# Out:
# INFO:process_C:Executing process process_C in Slurm
# INFO:process_C:Log folder for process process_C: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_C_20250218_143606_slurm_94
# INFO:process_C:Generating Slurm job script for process: process_C
# INFO:process_C:Preparing base script for process process_C
# INFO:process_C:Submitting process process_C with command: sbatch --partition cluster --mem 2GB --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_C_20250218_143606_slurm_94/process_C.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_C_20250218_143606_slurm_94/process_C.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_C_20250218_143606_slurm_94/process_C.slurm
# INFO:process_C:Process process_C submitted as Slurm job 489510.
# INFO:process_C:Job 489510 completed with exit code: 0:0

# %%
print(f"Process/Job ID: {output}")
print(f"Log Path: {process_c.log_path}")
# Out:
# Process/Job ID: 489510
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_C_20250218_143606_slurm_94

# %%
# Run with dependency
process_c = Process(name="process_C", param_file=["parameters/slurm.yaml", "parameters/slurm2.yaml"])
output_c = process_c.execute()

process_a = Process(name="process_A", param_file="parameters/slurm.yaml")
output_a = process_a.execute()

process_b = Process(name="process_B", param_file="parameters/slurm.yaml")
output_b = process_b.execute()
# Out:
# INFO:process_C:Executing process process_C in Slurm
# INFO:process_C:Log folder for process process_C: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_C_20250218_143744_slurm_8c
# INFO:process_C:Generating Slurm job script for process: process_C
# INFO:process_C:Preparing base script for process process_C
# INFO:process_C:Submitting process process_C with command: sbatch --partition cluster --mem 2GB --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_C_20250218_143744_slurm_8c/process_C.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_C_20250218_143744_slurm_8c/process_C.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_C_20250218_143744_slurm_8c/process_C.slurm
# INFO:process_C:Process process_C submitted as Slurm job 489511.
# INFO:process_A:Waiting for dependency process process_C to finish before executing process_A.
# INFO:process_A:Executing process process_A in Slurm
# INFO:process_A:Log folder for process process_A: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_A_20250218_143754_slurm_dd
# INFO:process_A:Generating Slurm job script for process: process_A
# INFO:process_A:Preparing base script for process process_A
# INFO:process_A:Submitting process process_A with command: sbatch --partition cluster --mem 2GB --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_A_20250218_143754_slurm_dd/process_A.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_A_20250218_143754_slurm_dd/process_A.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_A_20250218_143754_slurm_dd/process_A.slurm
# INFO:process_A:Process process_A submitted as Slurm job 489512.
# INFO:process_B:Waiting for dependency process process_A to finish before executing process_B.
# INFO:process_B:Executing process process_B in Slurm
# INFO:process_B:Log folder for process process_B: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_B_20250218_143805_slurm_90
# INFO:process_B:Generating Slurm job script for process: process_B
# INFO:process_B:Preparing base script for process process_B
# INFO:process_B:Submitting process process_B with command: sbatch --partition cluster --mem 2GB --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_B_20250218_143805_slurm_90/process_B.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_B_20250218_143805_slurm_90/process_B.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_B_20250218_143805_slurm_90/process_B.slurm
# INFO:process_B:Process process_B submitted as Slurm job 489513.
# INFO:process_C:Job 489511 completed with exit code: 0:0
# INFO:process_B:Job 489513 completed with exit code: 0:0
# INFO:process_A:Job 489512 completed with exit code: 0:0

# %%
print(f"Process/Job ID: {output_a}")
print(f"Log Path: {process_a.log_path}")
print(f"Process/Job ID: {output_b}")
print(f"Log Path: {process_b.log_path}")
print(f"Process/Job ID: {output_c}")
print(f"Log Path: {process_c.log_path}")
# Out:
# Process/Job ID: 489512
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_A_20250218_143754_slurm_dd
# Process/Job ID: 489513
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_B_20250218_143805_slurm_90
# Process/Job ID: 489511
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/process_C_20250218_143744_slurm_8c

# %%
# Run with apptainer container
process_apptainer = Process(
    name="slurm_apptainer",
    script="""#!/bin/bash
echo $HOSTNAME
echo $MY_VAR
""",
    environment='apptainer',
    container="/nexus/posix0/MAGE-flaski/service/images/python.sif",
    # environment_apptainer={
    #     "bind": ["/path/abc/:/abc/", "/path/def/:/def/"],
    #     "home": "/path/home"
    # },
    env={
        "MY_VAR": "APP_Value",
        "ANOTHER_VAR": "ANOTHER_VAR"
    },
    manager="slurm",
    manager_slurm={"partition":"dedicated", "mem":"4G"},
    logs_directory="logs_slurm"
)

# %%
output = process_apptainer.execute()
# Out:
# INFO:slurm_apptainer:Executing process slurm_apptainer in Slurm
# INFO:slurm_apptainer:Log folder for process slurm_apptainer: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/slurm_apptainer_20250218_145106_slurm_b0
# INFO:slurm_apptainer:Generating Slurm job script for process: slurm_apptainer
# INFO:slurm_apptainer:Preparing base script for process slurm_apptainer
# INFO:slurm_apptainer:Submitting process slurm_apptainer with command: sbatch --partition dedicated --mem 4G --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/slurm_apptainer_20250218_145106_slurm_b0/slurm_apptainer.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/slurm_apptainer_20250218_145106_slurm_b0/slurm_apptainer.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/slurm_apptainer_20250218_145106_slurm_b0/slurm_apptainer.slurm
# INFO:slurm_apptainer:Process slurm_apptainer submitted as Slurm job 489515.
# INFO:slurm_apptainer:Job 489515 completed with exit code: 0:0

# %%
print(f"Process/Job ID: {process_apptainer}")
print(f"Log Path: {process_apptainer.log_path}")
# Out:
# Process/Job ID: <jawm.process.Process object at 0x7fda4c84ad80>
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/slurm_apptainer_20250218_145106_slurm_b0

# %%
# Run with singularity container from parameter file
singularity_params = Process(name="singularity_params", param_file=["parameters/slurm.yaml", "parameters/slurm2.yaml"])
output = singularity_params.execute()
# Out:
# INFO:singularity_params:Executing process singularity_params in Slurm
# INFO:singularity_params:Log folder for process singularity_params: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/singularity_params_20250218_145805_slurm_a9
# INFO:singularity_params:Generating Slurm job script for process: singularity_params
# INFO:singularity_params:Preparing base script for process singularity_params
# INFO:singularity_params:Submitting process singularity_params with command: sbatch --partition cluster --mem 2GB --output /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/singularity_params_20250218_145805_slurm_a9/singularity_params.output --error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/singularity_params_20250218_145805_slurm_a9/singularity_params.error /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/singularity_params_20250218_145805_slurm_a9/singularity_params.slurm
# INFO:singularity_params:Process singularity_params submitted as Slurm job 489516.
# INFO:singularity_params:Job 489516 completed with exit code: 0:0

# %%
print(f"Process/Job ID: {singularity_params}")
print(f"Log Path: {singularity_params.log_path}")
# Out:
# Process/Job ID: <jawm.process.Process object at 0x7fda4c84a810>
# Log Path: /nexus/posix0/MAGE-flaski/service/posit/home/hamin/JAWM/notebook/logs_slurm/singularity_params_20250218_145805_slurm_a9
